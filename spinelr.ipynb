# %%
import seaborn as sns
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.models import model_from_json
import tensorflow as tf
import pandas as pd
import numpy as np
import statsmodels.api as sm
import sklearn
from csv import writer
import matplotlib.pyplot as plt

# %%
lst = []
ele = int(input("enter Pelvic Incidence"))
lst.append(ele)
ele = int(input("enter Pelvic Tilt"))
lst.append(ele)
ele = int(input("enter Lumbar Lordosis Angle"))
lst.append(ele)
ele = int(input("enter Sacral Slope"))
lst.append(ele)
ele = int(input("enter Pelvic Radius"))
lst.append(ele)
ele = int(input("enter Degree Spondylolisthesis"))
lst.append(ele)
ele = int(input("enter Pelvic Slope"))
lst.append(ele)
ele = int(input("enter Direct Tilt"))
lst.append(ele)
ele = int(input("enter Thoracic Slope"))
lst.append(ele)
ele = int(input("enter Cervical Tilt"))
lst.append(ele)
ele = int(input("enter Sacral Angle"))
lst.append(ele)
ele = int(input("enter Scoliosis Slope"))
lst.append(ele) # adding the element
ele = input("Target")
lst.append(ele) 
print(lst)
# Out:
# enter Pelvic Incidence4
# enter Pelvic Tilt4
# enter Lumbar Lordosis Angle4
# enter Sacral Slope4
# enter Pelvic Radius4
# enter Degree Spondylolisthesis4
# enter Pelvic Slope4
# enter Direct Tilt4
# enter Thoracic Slope4
# enter Cervical Tilt4
# enter Sacral Angle4
# enter Scoliosis Slope4
# TargetNormal
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 'Normal']

# %% [markdown]
# ##### from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# #import warnings
# #warnings.filterwarnings("ignore")
# import numpy as py
# from matplotlib import pyplot as plt

# %%
ds=pd.read_csv('s.csv');
ds[1][3]

# %%
df = pd.read_csv('Dataset_spine.csv');
df.describe()
#len(df)

df
# Out:
#           Col1       Col2       Col3       Col4        Col5       Col6  \
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
# ..         ...        ...        ...        ...         ...        ...
# 305  47.903565  13.616688  36.000000  34.286877  117.449062  -4.245395
# 306  53.936748  20.721496  29.220534  33.215251  114.365845  -0.421010
# 307  61.446597  22.694968  46.170347  38.751628  125.670725  -2.707880
# 308  45.252792   8.693157  41.583126  36.559635  118.545842   0.214750
# 309  33.841641   5.073991  36.641233  28.767649  123.945244  -0.199249
#
#          Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0    0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1    0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2    0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3    0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4    0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
# ..        ...      ...      ...       ...        ...      ...       ...
# 305  0.129744   7.8433  14.7484   8.51707 -15.728927  11.5472    Normal
# 306  0.047913  19.1986  18.1972   7.08745   6.013843  43.8693    Normal
# 307  0.081070  16.2059  13.5565   8.89572   3.564463  18.4151    Normal
# 308  0.159251  14.7334  16.0928   9.75922   5.767308  33.7192    Normal
# 309  0.674504  19.3825  17.6963  13.72929   1.783007  40.6049    Normal
#
#                                            Unnamed: 13
# 0                                                  NaN
# 1                                                  NaN
# 2    Prediction is done by using binary classificat...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
#
# [310 rows x 14 columns]

# %%
df.columns = ['Pelvic Incidence', 'Pelvic Tilt', 'Lumbar Lordosis Angle', 'Sacral Slope', 'Pelvic Radius',
              'Degree Spondylolisthesis', 'Pelvic Slope', 'Direct Tilt', 'Thoracic Slope', 'Cervical Tilt',
              'Sacral Angle', 'Scoliosis Slope','Target', '13']
df.drop('13', axis = 1, inplace = True)
df
# Out:
#      Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      Pelvic Radius  Degree Spondylolisthesis  Pelvic Slope  Direct Tilt  \
# 0        98.672917                 -0.254400      0.744503      12.5661
# 1       114.405425                  4.564259      0.415186      12.8874
# 2       105.985135                 -3.530317      0.474889      26.8343
# 3       101.868495                 11.211523      0.369345      23.5603
# 4       108.168725                  7.918501      0.543360      35.4940
# ..             ...                       ...           ...          ...
# 305     117.449062                 -4.245395      0.129744       7.8433
# 306     114.365845                 -0.421010      0.047913      19.1986
# 307     125.670725                 -2.707880      0.081070      16.2059
# 308     118.545842                  0.214750      0.159251      14.7334
# 309     123.945244                 -0.199249      0.674504      19.3825
#
#      Thoracic Slope  Cervical Tilt  Sacral Angle  Scoliosis Slope    Target
# 0           14.5386       15.30468    -28.658501          43.5123  Abnormal
# 1           17.5323       16.78486    -25.530607          16.1102  Abnormal
# 2           17.4861       16.65897    -29.031888          19.2221  Abnormal
# 3           12.7074       11.42447    -30.470246          18.8329  Abnormal
# 4           15.9546        8.87237    -16.378376          24.9171  Abnormal
# ..              ...            ...           ...              ...       ...
# 305         14.7484        8.51707    -15.728927          11.5472    Normal
# 306         18.1972        7.08745      6.013843          43.8693    Normal
# 307         13.5565        8.89572      3.564463          18.4151    Normal
# 308         16.0928        9.75922      5.767308          33.7192    Normal
# 309         17.6963       13.72929      1.783007          40.6049    Normal
#
# [310 rows x 13 columns]

# %%
df.describe()
# Out:
#        Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        Pelvic Radius  Degree Spondylolisthesis  Pelvic Slope  Direct Tilt  \
# count     310.000000                310.000000    310.000000   310.000000
# mean      117.920655                 26.296694      0.472979    21.321526
# std        13.317377                 37.559027      0.285787     8.639423
# min        70.082575                -11.058179      0.003220     7.027000
# 25%       110.709196                  1.603727      0.224367    13.054400
# 50%       118.268178                 11.767934      0.475989    21.907150
# 75%       125.467674                 41.287352      0.704846    28.954075
# max       163.071041                418.543082      0.998827    36.743900
#
#        Thoracic Slope  Cervical Tilt  Sacral Angle  Scoliosis Slope
# count      310.000000     310.000000    310.000000       310.000000
# mean        13.064511      11.933317    -14.053139        25.645981
# std          3.399713       2.893265     12.225582        10.450558
# min          7.037800       7.030600    -35.287375         7.007900
# 25%         10.417800       9.541140    -24.289522        17.189075
# 50%         12.938450      11.953835    -14.622856        24.931950
# 75%         15.889525      14.371810     -3.497094        33.979600
# max         19.324000      16.821080      6.972071        44.341200

# %%
with open('Dataset_spine.csv','a',newline='') as f_o:
    writer_object=writer(f_o)
    writer_object.writerow(lst)
    f_o.close()
df = pd.read_csv('Dataset_spine.csv');
df
#len(df)
# Out:
#           Col1       Col2       Col3       Col4        Col5       Col6  \
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
# ..         ...        ...        ...        ...         ...        ...
# 306  53.936748  20.721496  29.220534  33.215251  114.365845  -0.421010
# 307  61.446597  22.694968  46.170347  38.751628  125.670725  -2.707880
# 308  45.252792   8.693157  41.583126  36.559635  118.545842   0.214750
# 309  33.841641   5.073991  36.641233  28.767649  123.945244  -0.199249
# 310   4.000000   4.000000   4.000000   4.000000    4.000000   4.000000
#
#          Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0    0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1    0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2    0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3    0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4    0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
# ..        ...      ...      ...       ...        ...      ...       ...
# 306  0.047913  19.1986  18.1972   7.08745   6.013843  43.8693    Normal
# 307  0.081070  16.2059  13.5565   8.89572   3.564463  18.4151    Normal
# 308  0.159251  14.7334  16.0928   9.75922   5.767308  33.7192    Normal
# 309  0.674504  19.3825  17.6963  13.72929   1.783007  40.6049    Normal
# 310  4.000000   4.0000   4.0000   4.00000   4.000000   4.0000    Normal
#
#                                            Unnamed: 13
# 0                                                  NaN
# 1                                                  NaN
# 2    Prediction is done by using binary classificat...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
# [311 rows x 14 columns]

# %%
df.columns = ['Pelvic Incidence', 'Pelvic Tilt', 'Lumbar Lordosis Angle', 'Sacral Slope', 'Pelvic Radius',
              'Degree Spondylolisthesis', 'Pelvic Slope', 'Direct Tilt', 'Thoracic Slope', 'Cervical Tilt',
              'Sacral Angle', 'Scoliosis Slope','Target', '13']
df.drop('13', axis = 1, inplace = True)
df
# Out:
#      Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
# 310          4.000000     4.000000               4.000000      4.000000
#
#      Pelvic Radius  Degree Spondylolisthesis  Pelvic Slope  Direct Tilt  \
# 0        98.672917                 -0.254400      0.744503      12.5661
# 1       114.405425                  4.564259      0.415186      12.8874
# 2       105.985135                 -3.530317      0.474889      26.8343
# 3       101.868495                 11.211523      0.369345      23.5603
# 4       108.168725                  7.918501      0.543360      35.4940
# ..             ...                       ...           ...          ...
# 306     114.365845                 -0.421010      0.047913      19.1986
# 307     125.670725                 -2.707880      0.081070      16.2059
# 308     118.545842                  0.214750      0.159251      14.7334
# 309     123.945244                 -0.199249      0.674504      19.3825
# 310       4.000000                  4.000000      4.000000       4.0000
#
#      Thoracic Slope  Cervical Tilt  Sacral Angle  Scoliosis Slope    Target
# 0           14.5386       15.30468    -28.658501          43.5123  Abnormal
# 1           17.5323       16.78486    -25.530607          16.1102  Abnormal
# 2           17.4861       16.65897    -29.031888          19.2221  Abnormal
# 3           12.7074       11.42447    -30.470246          18.8329  Abnormal
# 4           15.9546        8.87237    -16.378376          24.9171  Abnormal
# ..              ...            ...           ...              ...       ...
# 306         18.1972        7.08745      6.013843          43.8693    Normal
# 307         13.5565        8.89572      3.564463          18.4151    Normal
# 308         16.0928        9.75922      5.767308          33.7192    Normal
# 309         17.6963       13.72929      1.783007          40.6049    Normal
# 310          4.0000        4.00000      4.000000           4.0000    Normal
#
# [311 rows x 13 columns]

# %%
'''fig, ax = plt.subplots(figsize=(15,8), ncols=4, nrows=3)

left   =  0.125  # the left side of the subplots of the figure
right  =  0.9    # the right side of the subplots of the figure
bottom =  0.1    # the bottom of the subplots of the figure
top    =  0.9    # the top of the subplots of the figure
wspace =  .5     # the amount of width reserved for blank space between subplots
hspace =  1.1    # the amount of height reserved for white space between subplots
plt.subplots_adjust(
    left    =  left, 
    bottom  =  bottom, 
    right   =  right, 
    top     =  top, 
    wspace  =  wspace, 
    hspace  =  hspace
)

y_title_margin = 1.2

plt.suptitle("Distribution of Values - Normal vs Abnormal", y = 1.09, fontsize=15)

sns.violinplot(x = 'Target', y  = 'Pelvic Incidence', data = df, ax=ax[0][0])
sns.violinplot(x = 'Target', y  = 'Pelvic Tilt', data = df, ax=ax[0][1], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Lumbar Lordosis Angle', data = df, ax=ax[0][2], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Sacral Slope', data = df, ax=ax[0][3], palette = flatui)

# second row
sns.violinplot(x = 'Target', y  = 'Pelvic Radius', data = df, ax=ax[1][0], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Degree Spondylolisthesis', data = df, ax=ax[1][1], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Pelvic Slope', data = df, ax=ax[1][2], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Direct Tilt', data = df, ax=ax[1][3], palette = flatui)

# third row
sns.violinplot(x = 'Target', y  = 'Thoracic Slope', data = df, ax=ax[2][0], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Cervical Tilt', data = df, ax=ax[2][1], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Sacral Angle', data = df, ax=ax[2][2], palette = flatui)

sns.violinplot(x = 'Target', y  = 'Scoliosis Slope', data = df, ax=ax[2][3], palette = flatui)'''
sns.set(style="darkgrid")
fig,ax=plt.subplots(2,3,figsize=(15,8))
sns.swarmplot("Target","Pelvic Incidence",data=df,ax=ax[0,0])
sns.swarmplot("Target","Pelvic Tilt",data=df,ax=ax[0,1])
sns.swarmplot("Target","Sacral Slope",data=df,ax=ax[0,2])
sns.swarmplot("Target","Degree Spondylolisthesis",data=df,ax=ax[1,1])
sns.swarmplot("Target","Lumbar Lordosis Angle",data=df,ax=ax[0,2])
sns.swarmplot("Target","Pelvic Radius",data=df,ax=ax[1,0])
sns.swarmplot("Target","Pelvic Slope",data=df,ax=ax[1,2])
#sns.swarmplot("Target","Directic Tilt",data=df,ax=ax[1,3])
#sns.swarmplot("Target","Directic Tilt",data=df,ax=ax[1,3])
#sns.swarmplot("Target","Directic Tilt",data=df,ax=ax[1,3])

plt.show()

#sns.swarmplot(data=df, x="Target", y="Scoliosis Slope", hue="size",ax=ax[2][3])

plt.figure(figsize=(8,5))
sns.countplot('Target',data=df,palette="viridis_r")
plt.show()
df['Target'].value_counts()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Abnormal    210
# Normal      101
# Name: Target, dtype: int64

# %%
from statsmodels.tools import add_constant as add_constant
df_constant = add_constant(df)
df["Target"]=pd.get_dummies(df["Target"],drop_first=True)

cols=df_constant.columns[:-1]
model=sm.Logit(df.Target,df_constant[cols])
result=model.fit()
result.summary()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1810: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1863: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 Target   No. Observations:                  311
# Model:                          Logit   Df Residuals:                      298
# Method:                           MLE   Df Model:                           12
# Date:                Sat, 12 Nov 2022   Pseudo R-squ.:                     inf
# Time:                        06:11:30   Log-Likelihood:                   -inf
# converged:                      False   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      -15.1816      3.554     -4.271      0.000     -22.148      -8.215
# Pelvic Incidence           -10.7921   4.24e+05  -2.55e-05      1.000    -8.3e+05     8.3e+05
# Pelvic Tilt                 10.7109   4.24e+05   2.53e-05      1.000    -8.3e+05     8.3e+05
# Lumbar Lordosis Angle        0.0221      0.023      0.948      0.343      -0.024       0.068
# Sacral Slope                10.8868   4.24e+05   2.57e-05      1.000    -8.3e+05     8.3e+05
# Pelvic Radius                0.1054      0.023      4.484      0.000       0.059       0.151
# Degree Spondylolisthesis    -0.1709      0.024     -7.196      0.000      -0.217      -0.124
# Pelvic Slope                 0.2188      0.688      0.318      0.750      -1.130       1.567
# Direct Tilt                 -0.0137      0.023     -0.587      0.557      -0.059       0.032
# Thoracic Slope               0.0522      0.058      0.902      0.367      -0.061       0.166
# Cervical Tilt               -0.0496      0.066     -0.747      0.455      -0.180       0.081
# Sacral Angle                -0.0049      0.016     -0.311      0.756      -0.036       0.026
# Scoliosis Slope              0.0098      0.019      0.527      0.598      -0.027       0.046
# ============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.12 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
'''def back_feature_elem (data_frame,dep_var,col_list):


    while len(col_list)>0 :
        model=sm.Logit(dep_var,data_frame[col_list])
        result=model.fit(disp=0)
        largest_pvalue=round(result.pvalues,3).nlargest(1)
        if largest_pvalue[0]<(0.05):
            return result
            break
        else:
            col_list=col_list.drop(largest_pvalue.index)

result=back_feature_elem(df_constant,df.Target,cols)
result.summary()'''
# Out:
# 'def back_feature_elem (data_frame,dep_var,col_list):\n\n\n    while len(col_list)>0 :\n        model=sm.Logit(dep_var,data_frame[col_list])\n        result=model.fit(disp=0)\n        largest_pvalue=round(result.pvalues,3).nlargest(1)\n        if largest_pvalue[0]<(0.05):\n            return result\n            break\n        else:\n            col_list=col_list.drop(largest_pvalue.index)\n\nresult=back_feature_elem(df_constant,df.Target,cols)\nresult.summary()'

# %%
y = df['Target']
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
y = label.fit_transform(y)


# X
dfx = df.drop(['Target'], axis = 1)
X = dfx

# Splitting into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.decomposition import PCA, KernelPCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# FEATURE SELECTION
selection = SelectKBest(k=1)

#FEATURE EXTRACTION
pca = PCA(n_components = 2)
k_pca = KernelPCA(n_components = 2)

# FEATURE UNION (FEATURE SELECTION + FEATURE EXTRACTION)
estimators = [('sel', selection),
              ('pca', pca),
              ('k_pca', k_pca)]  

combined = FeatureUnion(estimators)

X_features = combined.fit(X, y).transform(X)

# %%
log_regression = LogisticRegression()
pipeline = Pipeline([("features", combined), ("log", log_regression)])

# %%
components = [1,2,3,4,5]
original = [1,2,3,4]
Cs = np.logspace(-4, 4, 3)
param_grid = dict(features__pca__n_components=components,
                  features__k_pca__n_components=components,
                  features__sel__k=original,
                  log__C=Cs)

grid_search = GridSearchCV(pipeline, param_grid=param_grid, verbose=10)
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV 1/5; 1/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001
# [CV 1/5; 1/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001;, score=0.317 total time=   0.0s
# [CV 2/5; 1/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001
# [CV 2/5; 1/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001;, score=0.613 total time=   0.0s
# [CV 3/5; 1/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001
# [CV 3/5; 1/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001;, score=0.823 total time=   0.0s
# [CV 4/5; 1/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001
# [CV 4/5; 1/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001;, score=0.790 total time=   0.0s
# [CV 5/5; 1/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001
# [CV 5/5; 1/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=0.0001;, score=0.903 total time=   0.0s
# [CV 1/5; 2/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0
# [CV 1/5; 2/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0;, score=0.381 total time=   0.0s
# [CV 2/5; 2/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0
# [CV 2/5; 2/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0;, score=0.710 total time=   0.0s
# [CV 3/5; 2/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0
# [CV 3/5; 2/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0;, score=0.903 total time=   0.0s
# [CV 4/5; 2/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0
# [CV 4/5; 2/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0;, score=0.887 total time=   0.0s
# [CV 5/5; 2/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0
# [CV 5/5; 2/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=1.0;, score=0.919 total time=   0.0s
# [CV 1/5; 3/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0
# [CV 1/5; 3/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0;, score=0.381 total time=   0.0s
# [CV 2/5; 3/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0
# [CV 2/5; 3/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0;, score=0.710 total time=   0.0s
# [CV 3/5; 3/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0
# [CV 3/5; 3/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0;, score=0.903 total time=   0.0s
# [CV 4/5; 3/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0
# [CV 4/5; 3/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0;, score=0.887 total time=   0.0s
# [CV 5/5; 3/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0
# [CV 5/5; 3/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=1, log__C=10000.0;, score=0.919 total time=   0.0s
# [CV 1/5; 4/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001
# [CV 1/5; 4/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001;, score=0.317 total time=   0.0s
# [CV 2/5; 4/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001
# [CV 2/5; 4/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001;, score=0.629 total time=   0.0s
# [CV 3/5; 4/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001
# [CV 3/5; 4/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001;, score=0.823 total time=   0.0s
# [CV 4/5; 4/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001
# [CV 4/5; 4/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001;, score=0.806 total time=   0.0s
# [CV 5/5; 4/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001
# [CV 5/5; 4/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=0.0001;, score=0.887 total time=   0.0s
# [CV 1/5; 5/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0
# [CV 1/5; 5/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0;, score=0.381 total time=   0.0s
# [CV 2/5; 5/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0
# [CV 2/5; 5/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0;, score=0.726 total time=   0.0s
# [CV 3/5; 5/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0
# [CV 3/5; 5/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0;, score=0.887 total time=   0.0s
# [CV 4/5; 5/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0
# [CV 4/5; 5/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0;, score=0.919 total time=   0.0s
# [CV 5/5; 5/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0
# [CV 5/5; 5/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=1.0;, score=0.855 total time=   0.0s
# [CV 1/5; 6/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0
# [CV 1/5; 6/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0;, score=0.381 total time=   0.0s
# [CV 2/5; 6/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0
# [CV 2/5; 6/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0;, score=0.726 total time=   0.0s
# [CV 3/5; 6/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0
# [CV 3/5; 6/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0;, score=0.887 total time=   0.0s
# [CV 4/5; 6/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0
# [CV 4/5; 6/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0;, score=0.919 total time=   0.0s
# [CV 5/5; 6/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0
# [CV 5/5; 6/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=2, log__C=10000.0;, score=0.855 total time=   0.0s
# [CV 1/5; 7/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001
# [CV 1/5; 7/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001;, score=0.317 total time=   0.0s
# [CV 2/5; 7/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001
# [CV 2/5; 7/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001;, score=0.645 total time=   0.0s
# [CV 3/5; 7/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001
# [CV 3/5; 7/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001;, score=0.839 total time=   0.0s
# [CV 4/5; 7/300] START features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001
# [CV 4/5; 7/300] END features__k_pca__n_components=1, features__pca__n_components=1, features__sel__k=3, log__C=0.0001;, score=0.823 total time=   0.0s
# [CV
300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001;, score=0.349 total time=   0.0s
# [CV 2/5; 298/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001
# [CV 2/5; 298/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001;, score=0.726 total time=   0.0s
# [CV 3/5; 298/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001
# [CV 3/5; 298/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001;, score=0.919 total time=   0.0s
# [CV 4/5; 298/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001
# [CV 4/5; 298/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001;, score=0.839 total time=   0.0s
# [CV 5/5; 298/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001
# [CV 5/5; 298/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=0.0001;, score=0.855 total time=   0.0s
# [CV 1/5; 299/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0
# [CV 1/5; 299/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0;, score=0.429 total time=   0.0s
# [CV 2/5; 299/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0
# [CV 2/5; 299/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0;, score=0.742 total time=   0.0s
# [CV 3/5; 299/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0
# [CV 3/5; 299/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0;, score=0.919 total time=   0.0s
# [CV 4/5; 299/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0
# [CV 4/5; 299/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0;, score=0.935 total time=   0.0s
# [CV 5/5; 299/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0
# [CV 5/5; 299/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=1.0;, score=0.887 total time=   0.0s
# [CV 1/5; 300/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0
# [CV 1/5; 300/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0;, score=0.429 total time=   0.0s
# [CV 2/5; 300/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0
# [CV 2/5; 300/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0;, score=0.742 total time=   0.0s
# [CV 3/5; 300/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0
# [CV 3/5; 300/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0;, score=0.919 total time=   0.0s
# [CV 4/5; 300/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0
# [CV 4/5; 300/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0;, score=0.903 total time=   0.0s
# [CV 5/5; 300/300] START features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0
# [CV 5/5; 300/300] END features__k_pca__n_components=5, features__pca__n_components=5, features__sel__k=4, log__C=10000.0;, score=0.887 total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('sel',
#                                                                         SelectKBest(k=1)),
#                                                                        ('pca',
#                                                                         PCA(n_components=2)),
#                                                                        ('k_pca',
#                                                                         KernelPCA(n_components=2))])),
#                                        ('log', LogisticRegression())]),
#              param_grid={'features__k_pca__n_components': [1, 2, 3, 4, 5],
#                          'features__pca__n_components': [1, 2, 3, 4, 5],
#                          'features__sel__k': [1, 2, 3, 4],
#                          'log__C': array([1.e-04, 1.e+00, 1.e+04])},
#              verbose=10)

# %%
print("Best score: %0.3f" % grid_search.best_score_)
# Out:
# Best score: 0.805

# %%
selection = SelectKBest(k=3)

#FEATURE EXTRACTION
pca = PCA(n_components = 5)
k_pca = KernelPCA(n_components = 1)

# FEATURE UNION (FEATURE SELECTION + FEATURE EXTRACTION)
estimators = [('sel', selection),
              ('pca', pca),
              ('k_pca', k_pca)]  
combined = FeatureUnion(estimators)

X_features = combined.fit(X, y).transform(X)

# %%
from sklearn.svm import SVC
svc = SVC(kernel = 'rbf', random_state = 0)

pipeline2 = Pipeline([("features", combined), ("svc", svc)])

# %%
Cs = np.logspace(-4, 4, 3)
kernels = ['rbf','poly']
param_grid = dict(svc__C=Cs,
                 svc__kernel=kernels)

grid_search = GridSearchCV(pipeline2, param_grid=param_grid, verbose=10)
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START svc__C=0.0001, svc__kernel=rbf..............................
# [CV 1/5; 1/6] END svc__C=0.0001, svc__kernel=rbf;, score=0.667 total time=   0.1s
# [CV 2/5; 1/6] START svc__C=0.0001, svc__kernel=rbf..............................
# [CV 2/5; 1/6] END svc__C=0.0001, svc__kernel=rbf;, score=0.677 total time=   0.0s
# [CV 3/5; 1/6] START svc__C=0.0001, svc__kernel=rbf..............................
# [CV 3/5; 1/6] END svc__C=0.0001, svc__kernel=rbf;, score=0.677 total time=   0.0s
# [CV 4/5; 1/6] START svc__C=0.0001, svc__kernel=rbf..............................
# [CV 4/5; 1/6] END svc__C=0.0001, svc__kernel=rbf;, score=0.677 total time=   0.0s
# [CV 5/5; 1/6] START svc__C=0.0001, svc__kernel=rbf..............................
# [CV 5/5; 1/6] END svc__C=0.0001, svc__kernel=rbf;, score=0.677 total time=   0.0s
# [CV 1/5; 2/6] START svc__C=0.0001, svc__kernel=poly.............................
# [CV 1/5; 2/6] END svc__C=0.0001, svc__kernel=poly;, score=0.667 total time=   0.0s
# [CV 2/5; 2/6] START svc__C=0.0001, svc__kernel=poly.............................
# [CV 2/5; 2/6] END svc__C=0.0001, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 3/5; 2/6] START svc__C=0.0001, svc__kernel=poly.............................
# [CV 3/5; 2/6] END svc__C=0.0001, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 4/5; 2/6] START svc__C=0.0001, svc__kernel=poly.............................
# [CV 4/5; 2/6] END svc__C=0.0001, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 5/5; 2/6] START svc__C=0.0001, svc__kernel=poly.............................
# [CV 5/5; 2/6] END svc__C=0.0001, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 1/5; 3/6] START svc__C=1.0, svc__kernel=rbf.................................
# [CV 1/5; 3/6] END ..svc__C=1.0, svc__kernel=rbf;, score=0.333 total time=   0.0s
# [CV 2/5; 3/6] START svc__C=1.0, svc__kernel=rbf.................................
# [CV 2/5; 3/6] END ..svc__C=1.0, svc__kernel=rbf;, score=0.742 total time=   0.0s
# [CV 3/5; 3/6] START svc__C=1.0, svc__kernel=rbf.................................
# [CV 3/5; 3/6] END ..svc__C=1.0, svc__kernel=rbf;, score=0.935 total time=   0.0s
# [CV 4/5; 3/6] START svc__C=1.0, svc__kernel=rbf.................................
# [CV 4/5; 3/6] END ..svc__C=1.0, svc__kernel=rbf;, score=0.903 total time=   0.0s
# [CV 5/5; 3/6] START svc__C=1.0, svc__kernel=rbf.................................
# [CV 5/5; 3/6] END ..svc__C=1.0, svc__kernel=rbf;, score=0.855 total time=   0.0s
# [CV 1/5; 4/6] START svc__C=1.0, svc__kernel=poly................................
# [CV 1/5; 4/6] END .svc__C=1.0, svc__kernel=poly;, score=0.349 total time=   0.0s
# [CV 2/5; 4/6] START svc__C=1.0, svc__kernel=poly................................
# [CV 2/5; 4/6] END .svc__C=1.0, svc__kernel=poly;, score=0.726 total time=   0.0s
# [CV 3/5; 4/6] START svc__C=1.0, svc__kernel=poly................................
# [CV 3/5; 4/6] END .svc__C=1.0, svc__kernel=poly;, score=0.887 total time=   0.0s
# [CV 4/5; 4/6] START svc__C=1.0, svc__kernel=poly................................
# [CV 4/5; 4/6] END .svc__C=1.0, svc__kernel=poly;, score=0.887 total time=   0.0s
# [CV 5/5; 4/6] START svc__C=1.0, svc__kernel=poly................................
# [CV 5/5; 4/6] END .svc__C=1.0, svc__kernel=poly;, score=0.871 total time=   0.0s
# [CV 1/5; 5/6] START svc__C=10000.0, svc__kernel=rbf.............................
# [CV 1/5; 5/6] END svc__C=10000.0, svc__kernel=rbf;, score=0.476 total time=   0.0s
# [CV 2/5; 5/6] START svc__C=10000.0, svc__kernel=rbf.............................
# [CV 2/5; 5/6] END svc__C=10000.0, svc__kernel=rbf;, score=0.710 total time=   0.0s
# [CV 3/5; 5/6] START svc__C=10000.0, svc__kernel=rbf.............................
# [CV 3/5; 5/6] END svc__C=10000.0, svc__kernel=rbf;, score=0.823 total time=   0.0s
# [CV 4/5; 5/6] START svc__C=10000.0, svc__kernel=rbf.............................
# [CV 4/5; 5/6] END svc__C=10000.0, svc__kernel=rbf;, score=0.806 total time=   0.0s
# [CV 5/5; 5/6] START svc__C=10000.0, svc__kernel=rbf.............................
# [CV 5/5; 5/6] END svc__C=10000.0, svc__kernel=rbf;, score=0.839 total time=   0.0s
# [CV 1/5; 6/6] START svc__C=10000.0, svc__kernel=poly............................
# [CV 1/5; 6/6] END svc__C=10000.0, svc__kernel=poly;, score=0.460 total time=   0.0s
# [CV 2/5; 6/6] START svc__C=10000.0, svc__kernel=poly............................
# [CV 2/5; 6/6] END svc__C=10000.0, svc__kernel=poly;, score=0.694 total time=   0.0s
# [CV 3/5; 6/6] START svc__C=10000.0, svc__kernel=poly............................
# [CV 3/5; 6/6] END svc__C=10000.0, svc__kernel=poly;, score=0.903 total time=   0.0s
# [CV 4/5; 6/6] START svc__C=10000.0, svc__kernel=poly............................
# [CV 4/5; 6/6] END svc__C=10000.0, svc__kernel=poly;, score=0.855 total time=   0.0s
# [CV 5/5; 6/6] START svc__C=10000.0, svc__kernel=poly............................
# [CV 5/5; 6/6] END svc__C=10000.0, svc__kernel=poly;, score=0.839 total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('sel',
#                                                                         SelectKBest(k=3)),
#                                                                        ('pca',
#                                                                         PCA(n_components=5)),
#                                                                        ('k_pca',
#                                                                         KernelPCA(n_components=1))])),
#                                        ('svc', SVC(random_state=0))]),
#              param_grid={'svc__C': array([1.e-04, 1.e+00, 1.e+04]),
#                          'svc__kernel': ['rbf', 'poly']},
#              verbose=10)

# %%
print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(param_grid.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Best score: 0.754
# Best parameters set:
# 	svc__C: 1.0
# 	svc__kernel: 'rbf'

# %%
log_regression = LogisticRegression(C=10000)
final_model = Pipeline([("features", combined), ("log", log_regression )])

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = final_model, X = X_train, y = y_train, cv = 10)

avg_acc = accuracies.mean()
std_acc = accuracies.std()

print ("avg_acc: {} \nstd_acc: {}".format(avg_acc,std_acc))
# Out:
# avg_acc: 0.8553333333333335
# std_acc: 0.0875239649721403

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import keras.backend as K

K.clear_session()

model = Sequential()
model.add(Dense(24, input_dim = 12, activation='relu'))
model.add(Dense(6, activation ='relu'))
model.add(Dense(1, activation ='sigmoid'))
model.compile(SGD(lr=0.5),'binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 24)                312
#
#  dense_1 (Dense)             (None, 6)                 150
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 469
# Trainable params: 469
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\DELL\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.fit(X_train, y_train, epochs = 1000)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 3s 5ms/step - loss: 0.5980 - accuracy: 0.6694
# Epoch 2/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.7742
# Epoch 3/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8468
# Epoch 4/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8629
# Epoch 5/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8589
# Epoch 6/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.8911
# Epoch 7/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.8911
# Epoch 8/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.8992
# Epoch 9/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.8831
# Epoch 10/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2078 - accuracy: 0.9073
# Epoch 11/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1969 - accuracy: 0.
1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 322/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 323/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 324/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 325/1000
# 8/8 [==============================] - 0s 571us/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 326/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 327/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 328/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 329/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 330/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 331/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 332/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 333/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 334/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 335/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 336/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 337/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 338/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 339/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 340/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 341/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 342/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 343/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 344/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 345/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 346/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 347/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 348/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 349/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 350/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 351/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 352/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 353/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 354/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 355/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 356/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 357/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 358/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 359/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 360/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 361/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 362/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 363/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 364/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 365/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 366/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 367/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 368/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 369/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 370/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 371/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 372/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 373/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 374/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 375/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 376/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 377/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 378/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 379/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 380/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 381/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 382/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 383/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 384/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 385/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 386/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 387/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 388/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 389/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 390/1000
# 8/8 [==============================] - 0s 852us/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 391/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 392/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 393/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 394/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 395/1000
# 8/8 [==============================] - 0s 628us/step - loss: 9.9795e-04 - accuracy: 1.0000
# Epoch 396/1000
# 8/8 [==============================] - 0s 575us/step - loss: 9.9377e-04 - accuracy: 1.0000
# Epoch 397/1000
# 8/8 [==============================] - 0s 858us/step - loss: 9.9013e-04 - accuracy: 1.0000
# Epoch 398/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.8755e-04 - accuracy: 1.0000
# Epoch 399/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.8609e-04 - accuracy: 1.0000
# Epoch 400/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.8237e-04 - accuracy: 1.0000
# Epoch 401/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7736e-04 - accuracy: 1.0000
# Epoch 402/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7380e-04 - accuracy: 1.0000
# Epoch 403/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7077e-04 - accuracy: 1.0000
# Epoch 404/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6651e-04 - accuracy: 1.0000
# Epoch 405/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6436e-04 - accuracy: 1.0000
# Epoch 406/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6185e-04 - accuracy: 1.0000
# Epoch 407/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6143e-04 - accuracy: 1.0000
# Epoch 408/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6504e-04 - accuracy: 1.0000
# Epoch 409/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.5857e-04 - accuracy: 1.0000
# Epoch 410/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.5571e-04 - accuracy: 1.0000
# Epoch 411/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.5226e-04 - accuracy: 1.0000
# Epoch 412/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.4783e-04 - accuracy: 1.0000
# Epoch 413/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.4317e-04 - accuracy: 1.0000
# Epoch 414/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.4001e-04 - accuracy: 1.0000
# Epoch 415/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3613e-04 - accuracy: 1.0000
# Epoch 416/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3472e-04 - accuracy: 1.0000
# Epoch 417/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.3186e-04 - accuracy: 1.0000
# Epoch 418/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2903e-04 - accuracy: 1.0000
# Epoch 419/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2588e-04 - accuracy: 1.0000
# Epoch 420/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 9.2209e-04 - accuracy: 1.0000
# Epoch 421/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2085e-04 - accuracy: 1.0000
# Epoch 422/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1920e-04 - accuracy: 1.0000
# Epoch 423/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1599e-04 - accuracy: 1.0000
# Epoch 424/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1508e-04 - accuracy: 1.0000
# Epoch 425/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1500e-04 - accuracy: 1.0000
# Epoch 426/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1023e-04 - accuracy: 1.0000
# Epoch 427/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0645e-04 - accuracy: 1.0000
# Epoch 428/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0379e-04 - accuracy: 1.0000
# Epoch 429/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0171e-04 - accuracy: 1.0000
# Epoch 430/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9903e-04 - accuracy: 1.0000
# Epoch 431/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9503e-04 - accuracy: 1.0000
# Epoch 432/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9288e-04 - accuracy: 1.0000
# Epoch 433/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.9021e-04 - accuracy: 1.0000
# Epoch 434/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9167e-04 - accuracy: 1.0000
# Epoch 435/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8733e-04 - accuracy: 1.0000
# Epoch 436/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8435e-04 - accuracy: 1.0000
# Epoch 437/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8133e-04 - accuracy: 1.0000
# Epoch 438/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7733e-04 - accuracy: 1.0000
# Epoch 439/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7898e-04 - accuracy: 1.0000
# Epoch 440/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8310e-04 - accuracy: 1.0000
# Epoch 441/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.7575e-04 - accuracy: 1.0000
# Epoch 442/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.7132e-04 - accuracy: 1.0000
# Epoch 443/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.6839e-04 - accuracy: 1.0000
# Epoch 444/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6509e-04 - accuracy: 1.0000
# Epoch 445/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6200e-04 - accuracy: 1.0000
# Epoch 446/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5939e-04 - accuracy: 1.0000
# Epoch 447/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6009e-04 - accuracy: 1.0000
# Epoch 448/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6163e-04 - accuracy: 1.0000
# Epoch 449/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5714e-04 - accuracy: 1.0000
# Epoch 450/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5348e-04 - accuracy: 1.0000
# Epoch 451/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5047e-04 - accuracy: 1.0000
# Epoch 452/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4774e-04 - accuracy: 1.0000
# Epoch 453/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4421e-04 - accuracy: 1.0000
# Epoch 454/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4136e-04 - accuracy: 1.0000
# Epoch 455/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4396e-04 - accuracy: 1.0000
# Epoch 456/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3993e-04 - accuracy: 1.0000
# Epoch 457/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3663e-04 - accuracy: 1.0000
# Epoch 458/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3338e-04 - accuracy: 1.0000
# Epoch 459/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3085e-04 - accuracy: 1.0000
# Epoch 460/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2817e-04 - accuracy: 1.0000
# Epoch 461/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2558e-04 - accuracy: 1.0000
# Epoch 462/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2319e-04 - accuracy: 1.0000
# Epoch 463/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2138e-04 - accuracy: 1.0000
# Epoch 464/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1876e-04 - accuracy: 1.0000
# Epoch 465/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1659e-04 - accuracy: 1.0000
# Epoch 466/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1440e-04 - accuracy: 1.0000
# Epoch 467/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.1366e-04 - accuracy: 1.0000
# Epoch 468/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1090e-04 - accuracy: 1.0000
# Epoch 469/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.1066e-04 - accuracy: 1.0000
# Epoch 470/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.1337e-04 - accuracy: 1.0000
# Epoch 471/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.0849e-04 - accuracy: 1.0000
# Epoch 472/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.0543e-04 - accuracy: 1.0000
# Epoch 473/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.0327e-04 - accuracy: 1.0000
# Epoch 474/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 8.0184e-04 - accuracy: 1.0000
# Epoch 475/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 7.9862e-04 - accuracy: 1.0000
# Epoch 476/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 7.9580e-04 - accuracy: 1.0000
# Epoch 477/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 7.9319e-04 - accuracy: 1.0000
# Epoch 478/1000
# ...
# Epoch 848/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0867e-04 - accuracy: 1.0000
# Epoch 849/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0802e-04 - accuracy: 1.0000
# Epoch 850/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0736e-04 - accuracy: 1.0000
# Epoch 851/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0686e-04 - accuracy: 1.0000
# Epoch 852/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0608e-04 - accuracy: 1.0000
# Epoch 853/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0582e-04 - accuracy: 1.0000
# Epoch 854/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0582e-04 - accuracy: 1.0000
# Epoch 855/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0674e-04 - accuracy: 1.0000
# Epoch 856/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0551e-04 - accuracy: 1.0000
# Epoch 857/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0454e-04 - accuracy: 1.0000
# Epoch 858/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0378e-04 - accuracy: 1.0000
# Epoch 859/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0305e-04 - accuracy: 1.0000
# Epoch 860/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0334e-04 - accuracy: 1.0000
# Epoch 861/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0227e-04 - accuracy: 1.0000
# Epoch 862/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0148e-04 - accuracy: 1.0000
# Epoch 863/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0088e-04 - accuracy: 1.0000
# Epoch 864/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0015e-04 - accuracy: 1.0000
# Epoch 865/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9938e-04 - accuracy: 1.0000
# Epoch 866/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9879e-04 - accuracy: 1.0000
# Epoch 867/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9815e-04 - accuracy: 1.0000
# Epoch 868/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9750e-04 - accuracy: 1.0000
# Epoch 869/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9687e-04 - accuracy: 1.0000
# Epoch 870/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9680e-04 - accuracy: 1.0000
# Epoch 871/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9617e-04 - accuracy: 1.0000
# Epoch 872/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9552e-04 - accuracy: 1.0000
# Epoch 873/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9596e-04 - accuracy: 1.0000
# Epoch 874/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9549e-04 - accuracy: 1.0000
# Epoch 875/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9543e-04 - accuracy: 1.0000
# Epoch 876/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9441e-04 - accuracy: 1.0000
# Epoch 877/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9364e-04 - accuracy: 1.0000
# Epoch 878/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9293e-04 - accuracy: 1.0000
# Epoch 879/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9223e-04 - accuracy: 1.0000
# Epoch 880/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9161e-04 - accuracy: 1.0000
# Epoch 881/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9103e-04 - accuracy: 1.0000
# Epoch 882/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9047e-04 - accuracy: 1.0000
# Epoch 883/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8988e-04 - accuracy: 1.0000
# Epoch 884/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9037e-04 - accuracy: 1.0000
# Epoch 885/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8958e-04 - accuracy: 1.0000
# Epoch 886/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8896e-04 - accuracy: 1.0000
# Epoch 887/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8827e-04 - accuracy: 1.0000
# Epoch 888/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8913e-04 - accuracy: 1.0000
# Epoch 889/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8824e-04 - accuracy: 1.0000
# Epoch 890/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8735e-04 - accuracy: 1.0000
# Epoch 891/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.8664e-04 - accuracy: 1.0000
# Epoch 892/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8650e-04 - accuracy: 1.0000
# Epoch 893/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8570e-04 - accuracy: 1.0000
# Epoch 894/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8504e-04 - accuracy: 1.0000
# Epoch 895/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8460e-04 - accuracy: 1.0000
# Epoch 896/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8388e-04 - accuracy: 1.0000
# Epoch 897/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8341e-04 - accuracy: 1.0000
# Epoch 898/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8275e-04 - accuracy: 1.0000
# Epoch 899/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8220e-04 - accuracy: 1.0000
# Epoch 900/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8163e-04 - accuracy: 1.0000
# Epoch 901/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8210e-04 - accuracy: 1.0000
# Epoch 902/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8280e-04 - accuracy: 1.0000
# Epoch 903/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8170e-04 - accuracy: 1.0000
# Epoch 904/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8084e-04 - accuracy: 1.0000
# Epoch 905/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.8024e-04 - accuracy: 1.0000
# Epoch 906/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7945e-04 - accuracy: 1.0000
# Epoch 907/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7923e-04 - accuracy: 1.0000
# Epoch 908/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7864e-04 - accuracy: 1.0000
# Epoch 909/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7808e-04 - accuracy: 1.0000
# Epoch 910/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7753e-04 - accuracy: 1.0000
# Epoch 911/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7693e-04 - accuracy: 1.0000
# Epoch 912/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7632e-04 - accuracy: 1.0000
# Epoch 913/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7572e-04 - accuracy: 1.0000
# Epoch 914/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7513e-04 - accuracy: 1.0000
# Epoch 915/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7474e-04 - accuracy: 1.0000
# Epoch 916/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7477e-04 - accuracy: 1.0000
# Epoch 917/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7477e-04 - accuracy: 1.0000
# Epoch 918/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7454e-04 - accuracy: 1.0000
# Epoch 919/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7383e-04 - accuracy: 1.0000
# Epoch 920/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7312e-04 - accuracy: 1.0000
# Epoch 921/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7294e-04 - accuracy: 1.0000
# Epoch 922/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7227e-04 - accuracy: 1.0000
# Epoch 923/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7159e-04 - accuracy: 1.0000
# Epoch 924/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7100e-04 - accuracy: 1.0000
# Epoch 925/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7042e-04 - accuracy: 1.0000
# Epoch 926/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6985e-04 - accuracy: 1.0000
# Epoch 927/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6936e-04 - accuracy: 1.0000
# Epoch 928/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6984e-04 - accuracy: 1.0000
# Epoch 929/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6991e-04 - accuracy: 1.0000
# Epoch 930/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6950e-04 - accuracy: 1.0000
# Epoch 931/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6916e-04 - accuracy: 1.0000
# Epoch 932/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6845e-04 - accuracy: 1.0000
# Epoch 933/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6774e-04 - accuracy: 1.0000
# Epoch 934/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6715e-04 - accuracy: 1.0000
# Epoch 935/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6652e-04 - accuracy: 1.0000
# Epoch 936/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6613e-04 - accuracy: 1.0000
# Epoch 937/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6593e-04 - accuracy: 1.0000
# Epoch 938/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6541e-04 - accuracy: 1.0000
# Epoch 939/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6481e-04 - accuracy: 1.0000
# Epoch 940/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6426e-04 - accuracy: 1.0000
# Epoch 941/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6365e-04 - accuracy: 1.0000
# Epoch 942/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.6317e-04 - accuracy: 1.0000
# Epoch 943/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6266e-04 - accuracy: 1.0000
# Epoch 944/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6218e-04 - accuracy: 1.0000
# Epoch 945/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6196e-04 - accuracy: 1.0000
# Epoch 946/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6213e-04 - accuracy: 1.0000
# Epoch 947/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6145e-04 - accuracy: 1.0000
# Epoch 948/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6081e-04 - accuracy: 1.0000
# Epoch 949/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6037e-04 - accuracy: 1.0000
# Epoch 950/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.6007e-04 - accuracy: 1.0000
# Epoch 951/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5952e-04 - accuracy: 1.0000
# Epoch 952/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5901e-04 - accuracy: 1.0000
# Epoch 953/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5847e-04 - accuracy: 1.0000
# Epoch 954/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5812e-04 - accuracy: 1.0000
# Epoch 955/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5746e-04 - accuracy: 1.0000
# Epoch 956/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5696e-04 - accuracy: 1.0000
# Epoch 957/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5668e-04 - accuracy: 1.0000
# Epoch 958/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5651e-04 - accuracy: 1.0000
# Epoch 959/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5592e-04 - accuracy: 1.0000
# Epoch 960/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5543e-04 - accuracy: 1.0000
# Epoch 961/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5497e-04 - accuracy: 1.0000
# Epoch 962/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5544e-04 - accuracy: 1.0000
# Epoch 963/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.5492e-04 - accuracy: 1.0000
# Epoch 964/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5431e-04 - accuracy: 1.0000
# Epoch 965/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5365e-04 - accuracy: 1.0000
# Epoch 966/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5315e-04 - accuracy: 1.0000
# Epoch 967/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5270e-04 - accuracy: 1.0000
# Epoch 968/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5214e-04 - accuracy: 1.0000
# Epoch 969/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5189e-04 - accuracy: 1.0000
# Epoch 970/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5137e-04 - accuracy: 1.0000
# Epoch 971/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5100e-04 - accuracy: 1.0000
# Epoch 972/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5047e-04 - accuracy: 1.0000
# Epoch 973/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5021e-04 - accuracy: 1.0000
# Epoch 974/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5041e-04 - accuracy: 1.0000
# Epoch 975/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4978e-04 - accuracy: 1.0000
# Epoch 976/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4912e-04 - accuracy: 1.0000
# Epoch 977/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4984e-04 - accuracy: 1.0000
# Epoch 978/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4878e-04 - accuracy: 1.0000
# Epoch 979/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4818e-04 - accuracy: 1.0000
# Epoch 980/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4763e-04 - accuracy: 1.0000
# Epoch 981/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4715e-04 - accuracy: 1.0000
# Epoch 982/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4660e-04 - accuracy: 1.0000
# Epoch 983/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4616e-04 - accuracy: 1.0000
# Epoch 984/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4566e-04 - accuracy: 1.0000
# Epoch 985/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.4515e-04 - accuracy: 1.0000
# Epoch 986/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4471e-04 - accuracy: 1.0000
# Epoch 987/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4425e-04 - accuracy: 1.0000
# Epoch 988/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4477e-04 - accuracy: 1.0000
# Epoch 989/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4393e-04 - accuracy: 1.0000
# Epoch 990/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4338e-04 - accuracy: 1.0000
# Epoch 991/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4332e-04 - accuracy: 1.0000
# Epoch 992/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4394e-04 - accuracy: 1.0000
# Epoch 993/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4330e-04 - accuracy: 1.0000
# Epoch 994/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4277e-04 - accuracy: 1.0000
# Epoch 995/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4228e-04 - accuracy: 1.0000
# Epoch 996/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4173e-04 - accuracy: 1.0000
# Epoch 997/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4112e-04 - accuracy: 1.0000
# Epoch 998/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4061e-04 - accuracy: 1.0000
# Epoch 999/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4008e-04 - accuracy: 1.0000
# Epoch 1000/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3968e-04 - accuracy: 1.0000

# %%
y_pred = model.predict(X_test)
y_class_pred = y_pred > 0.5
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_class_pred)
acc
# Out:
# 2/2 [==============================] - 0s 12ms/step
# 0.6825396825396826

# %%
    model_params ={
    "svm": {
        "model" : SVC(gamma="auto"),
        "params": {
            "C" : [1,10,20],
            "kernel": ["rbf"],
            "random_state":[0,10,100]
        }
    },
    
    "decision_tree":{
        "model": DecisionTreeClassifier(),
        "params":{
            "criterion": ["entropy","gini"],
            "max_depth": [5,8,9],
            "random_state":[0,10,100] 
    }
    },
    "random_forest":{
        "model": RandomForestClassifier(),
        "params": {
            "n_estimators" : [1,5,10],
            "max_depth" : [5,8,9],
            "random_state":[0,10,100]
        }
    },
    "naive_bayes":{
        "model": GaussianNB(),
        "params": {}
    },
    "logistic_regression":{
        "model" : LogisticRegression(solver='liblinear',multi_class = 'auto'),
        "params":{
            "C" : [1,5,10],
            "random_state":[0,10,100]
        }
    },
    "knn" : {
        "model" : KNeighborsClassifier(),
        "params": {
            "n_neighbors" : [5,12,13]
        }
    }
    
    
}

# %%
from sklearn.preprocessing import StandardScaler
x = df.drop("Target",axis=1)
scaler = StandardScaler()
x = scaler.fit_transform(x)

scores =[]
for model_name,mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp["params"],cv=12,return_train_score=False)
    clf.fit(x,y)
    scores.append({
        "Model" : model_name,
        "Best_Score": clf.best_score_,
        "Best_Params": clf.best_params_
    })

# %%
result_score = pd.DataFrame(scores, columns = ["Model","Best_Score","Best_Params"])

# %%
result_score
# Out:
#                  Model  Best_Score  \
# 0                  svm    0.794615
# 1        decision_tree    0.752692
# 2        random_forest    0.829744
# 3          naive_bayes    0.762692
# 4  logistic_regression    0.817051
# 5                  knn    0.756026
#
#                                          Best_Params
# 0      {'C': 10, 'kernel': 'rbf', 'random_state': 0}
# 1  {'criterion': 'entropy', 'max_depth': 9, 'rand...
# 2  {'max_depth': 9, 'n_estimators': 10, 'random_s...
# 3                                                 {}
# 4                        {'C': 5, 'random_state': 0}
# 5                                {'n_neighbors': 12}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state= 10)
clf_rf = RandomForestClassifier(max_depth = 8,n_estimators =10,random_state=0)
clf_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=10, random_state=0)

# %%
y_pred = clf_rf.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334

# %%
#clf_lr = LogisticRegression(C=12,random_state = 100)
#clf_lr.fit(x_train,y_train)

# %%
#y_pred = clf_lr.predict(x_test)
#accuracy_score(y_test,y_pred)

# %%
result = pd.DataFrame({"Actual_Value": y_test, "Predicted_Value": y_pred})

# %%
result
# Out:
#     Actual_Value  Predicted_Value
# 0              0                1
# 1              1                1
# 2              0                0
# 3              1                1
# 4              1                1
# ..           ...              ...
# 73             0                0
# 74             0                1
# 75             0                0
# 76             1                1
# 77             0                0
#
# [78 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap='gist_ncar')
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)

y_pred_prob=logreg.predict_proba(x_test)[:,:]
y_pred_prob_df=pd.DataFrame(data=y_pred_prob, columns=['Prob of abnormal spine (0)','Prb of normal spine (1)'])
y_pred_prob_df.head()
# Out:
#    Prob of abnormal spine (0)  Prb of normal spine (1)
# 0                    0.435028                 0.564972
# 1                    0.141480                 0.858520
# 2                    0.998119                 0.001881
# 3                    0.151404                 0.848596
# 4                    0.222763                 0.777237

# %%
from sklearn.preprocessing import binarize
for i in range(1,5):
    cm2=0
    y_pred_prob_yes=logreg.predict_proba(x_test)
    y_pred2=binarize(y_pred_prob_yes,i/10)[:,1]
    cm2=confusion_matrix(y_test,y_pred2)
    print ('With',i/10,'threshold  is ','\n',cm2,'\n',
            'with',cm2[0,0]+cm2[1,1],'correct predictions and',cm2[1,0],'Type II errors( False Negatives)','\n\n',
          'Sensitivity: ',cm2[1,1]/(float(cm2[1,1]+cm2[1,0])),'Specificity: ',cm2[0,0]/(float(cm2[0,0]+cm2[0,1])),'\n\n\n')
# Out:
# With 0.1 threshold  is
#  [[28 28]
#  [ 0 22]]
#  with 50 correct predictions and 0 Type II errors( False Negatives)
#
#  Sensitivity:  1.0 Specificity:  0.5
#
#
#
# With 0.2 threshold  is
#  [[35 21]
#  [ 0 22]]
#  with 57 correct predictions and 0 Type II errors( False Negatives)
#
#  Sensitivity:  1.0 Specificity:  0.625
#
#
#
# With 0.3 threshold  is
#  [[39 17]
#  [ 1 21]]
#  with 60 correct predictions and 1 Type II errors( False Negatives)
#
#  Sensitivity:  0.9545454545454546 Specificity:  0.6964285714285714
#
#
#
# With 0.4 threshold  is
#  [[44 12]
#  [ 2 20]]
#  with 64 correct predictions and 2 Type II errors( False Negatives)
#
#  Sensitivity:  0.9090909090909091 Specificity:  0.7857142857142857
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass threshold=0.1 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass threshold=0.2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass threshold=0.3 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass threshold=0.4 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob_yes[:,1])
plt.plot(fpr,tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Heart disease classifier')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)
sklearn.metrics.roc_auc_score(y_test,y_pred_prob_yes[:,1])
# Out:
# 0.9163961038961038

# %%
print('Abnormal', round(df['Target'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Normal', round(df['Target'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
# Out:
# Abnormal 67.52 % of the dataset
# Normal 32.48 % of the dataset
